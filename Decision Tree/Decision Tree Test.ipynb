# %%
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
path = '/content/drive/MyDrive/Data science/Colab Notebooks'
os.chdir(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
# load dataset
pima = pd.read_csv('diabetes.csv', header = 0, names=col_names)

# %%
pima.head()
# Out:
#    pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0         6      148  72    35        0  33.6     0.627   50      1
# 1         1       85  66    29        0  26.6     0.351   31      0
# 2         8      183  64     0        0  23.3     0.672   32      1
# 3         1       89  66    23       94  28.1     0.167   21      0
# 4         0      137  40    35      168  43.1     2.288   33      1

# %%
#split dataset in features and target variable
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
X = pima[feature_cols] # Features
y = pima.label # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = tree.DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6883116883116883

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.40381944444444445, 0.96875, 'X[4] <= 129.5\ngini = 0.449\nsamples = 537\nvalue = [354, 183]'),
#  Text(0.146875, 0.90625, 'X[2] <= 26.3\ngini = 0.329\nsamples = 357\nvalue = [283, 74]'),
#  Text(0.044444444444444446, 0.84375, 'X[2] <= 9.1\ngini = 0.06\nsamples = 97\nvalue = [94, 3]'),
#  Text(0.022222222222222223, 0.78125, 'X[3] <= 28.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.011111111111111112, 0.71875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.03333333333333333, 0.71875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06666666666666667, 0.78125, 'X[6] <= 0.669\ngini = 0.022\nsamples = 91\nvalue = [90, 1]'),
#  Text(0.05555555555555555, 0.71875, 'gini = 0.0\nsamples = 76\nvalue = [76, 0]'),
#  Text(0.07777777777777778, 0.71875, 'X[6] <= 0.705\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.06666666666666667, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08888888888888889, 0.65625, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.24930555555555556, 0.84375, 'X[3] <= 27.5\ngini = 0.397\nsamples = 260\nvalue = [189, 71]'),
#  Text(0.14444444444444443, 0.78125, 'X[2] <= 45.4\ngini = 0.243\nsamples = 120\nvalue = [103, 17]'),
#  Text(0.12222222222222222, 0.71875, 'X[0] <= 7.0\ngini = 0.212\nsamples = 116\nvalue = [102, 14]'),
#  Text(0.1111111111111111, 0.65625, 'X[5] <= 12.0\ngini = 0.201\nsamples = 115\nvalue = [102, 13]'),
#  Text(0.1, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12222222222222222, 0.59375, 'X[6] <= 1.272\ngini = 0.188\nsamples = 114\nvalue = [102, 12]'),
#  Text(0.1, 0.53125, 'X[2] <= 30.95\ngini = 0.165\nsamples = 110\nvalue = [100, 10]'),
#  Text(0.08888888888888889, 0.46875, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(0.1111111111111111, 0.46875, 'X[5] <= 53.0\ngini = 0.254\nsamples = 67\nvalue = [57, 10]'),
#  Text(0.08333333333333333, 0.40625, 'X[0] <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.07222222222222222, 0.34375, 'X[6] <= 0.566\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.06111111111111111, 0.28125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.08333333333333333, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09444444444444444, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1388888888888889, 0.40625, 'X[6] <= 0.652\ngini = 0.203\nsamples = 61\nvalue = [54, 7]'),
#  Text(0.11666666666666667, 0.34375, 'X[1] <= 36.5\ngini = 0.15\nsamples = 49\nvalue = [45, 4]'),
#  Text(0.10555555555555556, 0.28125, 'X[1] <= 34.0\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.09444444444444444, 0.21875, 'X[4] <= 111.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.07222222222222222, 0.15625, 'X[6] <= 0.458\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.06111111111111111, 0.09375, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.08333333333333333, 0.09375, 'X[2] <= 35.3\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.07222222222222222, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09444444444444444, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11666666666666667, 0.15625, 'X[5] <= 72.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.10555555555555556, 0.09375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.12777777777777777, 0.09375, 'X[2] <= 34.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11666666666666667, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1388888888888889, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11666666666666667, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12777777777777777, 0.28125, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(0.16111111111111112, 0.34375, 'X[1] <= 65.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.15, 0.28125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.17222222222222222, 0.28125, 'X[2] <= 38.55\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.16111111111111112, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.18333333333333332, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14444444444444443, 0.53125, 'X[6] <= 1.496\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.13333333333333333, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15555555555555556, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13333333333333333, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16666666666666666, 0.71875, 'X[3] <= 22.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.15555555555555556, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17777777777777778, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3541666666666667, 0.78125, 'X[6] <= 0.563\ngini = 0.474\nsamples = 140\nvalue = [86, 54]'),
#  Text(0.2638888888888889, 0.71875, 'X[4] <= 101.5\ngini = 0.408\nsamples = 98\nvalue = [70, 28]'),
#  Text(0.2, 0.65625, 'X[5] <= 27.0\ngini = 0.208\nsamples = 34\nvalue = [30, 4]'),
#  Text(0.18888888888888888, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2111111111111111, 0.59375, 'X[3] <= 42.5\ngini = 0.165\nsamples = 33\nvalue = [30, 3]'),
#  Text(0.2, 0.53125, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(0.2222222222222222, 0.53125, 'X[4] <= 97.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.2111111111111111, 0.46875, 'X[4] <= 76.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.2, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2222222222222222, 0.40625, 'X[2] <= 36.2\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.2111111111111111, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.23333333333333334, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23333333333333334, 0.46875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3277777777777778, 0.65625, 'X[5] <= 67.0\ngini = 0.469\nsamples = 64\nvalue = [40, 24]'),
#  Text(0.28888888888888886, 0.59375, 'X[5] <= 58.0\ngini = 0.465\nsamples = 19\nvalue = [7, 12]'),
#  Text(0.26666666666666666, 0.53125, 'X[4] <= 117.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.25555555555555554, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2777777777777778, 0.46875, 'X[2] <= 34.25\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.26666666666666666, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.28888888888888886, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3111111111111111, 0.53125, 'X[6] <= 0.425\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.3, 0.46875, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.32222222222222224, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36666666666666664, 0.59375, 'X[2] <= 43.1\ngini = 0.391\nsamples = 45\nvalue = [33, 12]'),
#  Text(0.35555555555555557, 0.53125, 'X[4] <= 102.5\ngini = 0.337\nsamples = 42\nvalue = [33, 9]'),
#  Text(0.34444444444444444, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.36666666666666664, 0.46875, 'X[2] <= 34.6\ngini = 0.289\nsamples = 40\nvalue = [33, 7]'),
#  Text(0.35555555555555557, 0.40625, 'X[3] <= 35.0\ngini = 0.434\nsamples = 22\nvalue = [15, 7]'),
#  Text(0.34444444444444444, 0.34375, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.36666666666666664, 0.34375, 'X[4] <= 123.5\ngini = 0.492\nsamples = 16\nvalue = [9, 7]'),
#  Text(0.35555555555555557, 0.28125, 'X[6] <= 0.375\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.34444444444444444, 0.21875, 'X[6] <= 0.258\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.3333333333333333, 0.15625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.35555555555555557, 0.15625, 'X[2] <= 32.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.34444444444444444, 0.09375, 'X[4] <= 118.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3333333333333333, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.35555555555555557, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36666666666666664, 0.09375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.36666666666666664, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.37777777777777777, 0.28125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.37777777777777777, 0.40625, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.37777777777777777, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4444444444444444, 0.71875, 'X[0] <= 8.5\ngini = 0.472\nsamples = 42\nvalue = [16, 26]'),
#  Text(0.43333333333333335, 0.65625, 'X[5] <= 87.0\ngini = 0.5\nsamples = 33\nvalue = [16, 17]'),
#  Text(0.4222222222222222, 0.59375, 'X[4] <= 97.0\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.4111111111111111, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.43333333333333335, 0.53125, 'X[4] <= 116.5\ngini = 0.413\nsamples = 24\nvalue = [7, 17]'),
#  Text(0.4111111111111111, 0.46875, 'X[6] <= 1.395\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.4, 0.40625, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.4222222222222222, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.45555555555555555, 0.46875, 'X[1] <= 78.0\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.4444444444444444, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4666666666666667, 0.40625, 'X[4] <= 123.5\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.45555555555555555, 0.34375, 'X[4] <= 119.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.4444444444444444, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4666666666666667, 0.28125, 'X[6] <= 0.712\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.45555555555555555, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4777777777777778, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4777777777777778, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4444444444444444, 0.59375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.45555555555555555, 0.65625, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.6607638888888889, 0.90625, 'X[2] <= 27.85\ngini = 0.478\nsamples = 180\nvalue = [71, 109]'),
#  Text(0.5, 0.84375, 'X[4] <= 145.5\ngini = 0.375\nsamples = 36\nvalue = [27, 9]'),
#  Text(0.4777777777777778, 0.78125, 'X[3] <= 59.5\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.4666666666666667, 0.71875, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.4888888888888889, 0.71875, 'X[2] <= 25.25\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.4777777777777778, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5222222222222223, 0.78125, 'X[3] <= 25.5\ngini = 0.498\nsamples = 17\nvalue = [9, 8]'),
#  Text(0.5111111111111111, 0.71875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5333333333333333, 0.71875, 'X[3] <= 62.0\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.5222222222222223, 0.65625, 'X[2] <= 27.0\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.5, 0.59375, 'X[2] <= 22.15\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.4888888888888889, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5111111111111111, 0.53125, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5444444444444444, 0.59375, 'X[5] <= 32.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5333333333333333, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5555555555555556, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5444444444444444, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8215277777777777, 0.84375, 'X[4] <= 158.5\ngini = 0.424\nsamples = 144\nvalue = [44, 100]'),
#  Text(0.6930555555555555, 0.78125, 'X[3] <= 30.5\ngini = 0.487\nsamples = 88\nvalue = [37, 51]'),
#  Text(0.6166666666666667, 0.71875, 'X[5] <= 23.0\ngini = 0.49\nsamples = 42\nvalue = [24, 18]'),
#  Text(0.6055555555555555, 0.65625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6277777777777778, 0.65625, 'X[5] <= 88.0\ngini = 0.465\nsamples = 38\nvalue = [24, 14]'),
#  Text(0.6166666666666667, 0.59375, 'X[5] <= 72.0\ngini = 0.444\nsamples = 36\nvalue = [24, 12]'),
#  Text(0.5777777777777777, 0.53125, 'X[2] <= 33.75\ngini = 0.5\nsamples = 20\nvalue = [10, 10]'),
#  Text(0.5555555555555556, 0.46875, 'X[2] <= 31.05\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.5444444444444444, 0.40625, 'X[5] <= 58.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.5333333333333333, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5555555555555556, 0.34375, 'X[0] <= 4.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5444444444444444, 0.28125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5666666666666667, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5666666666666667, 0.40625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6, 0.46875, 'X[6] <= 0.535\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.5888888888888889, 0.40625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6111111111111112, 0.40625, 'X[4] <= 136.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6222222222222222, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6555555555555556, 0.53125, 'X[4] <= 157.5\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.6444444444444445, 0.46875, 'X[5] <= 85.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.6333333333333333, 0.40625, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.6555555555555556, 0.40625, 'X[4] <= 142.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6444444444444445, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6388888888888888, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7694444444444445, 0.71875, 'X[2] <= 34.05\ngini = 0.405\nsamples = 46\nvalue = [13, 33]'),
#  Text(0.7222222222222222, 0.65625, 'X[5] <= 75.0\ngini = 0.49\nsamples = 21\nvalue = [9, 12]'),
#  Text(0.7111111111111111, 0.59375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7333333333333333, 0.59375, 'X[4] <= 143.0\ngini = 0.415\nsamples = 17\nvalue = [5, 12]'),
#  Text(0.7222222222222222, 0.53125, 'X[3] <= 47.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.7111111111111111, 0.46875, 'X[2] <= 33.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.7, 0.40625, 'X[1] <= 147.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6888888888888889, 0.34375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7111111111111111, 0.34375, 'X[1] <= 317.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7222222222222222, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7222222222222222, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7333333333333333, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7444444444444445, 0.53125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8166666666666667, 0.65625, 'X[6] <= 1.088\ngini = 0.269\nsamples = 25\nvalue = [4, 21]'),
#  Text(0.7888888888888889, 0.59375, 'X[1] <= 306.5\ngini = 0.172\nsamples = 21\nvalue = [2, 19]'),
#  Text(0.7666666666666667, 0.53125, 'X[6] <= 0.222\ngini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(0.7555555555555555, 0.46875, 'X[6] <= 0.171\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7444444444444445, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7666666666666667, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7777777777777778, 0.46875, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.8111111111111111, 0.53125, 'X[4] <= 142.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8222222222222222, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8444444444444444, 0.59375, 'X[1] <= 147.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8333333333333334, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8555555555555555, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.95, 0.78125, 'X[6] <= 1.157\ngini = 0.219\nsamples = 56\nvalue = [7, 49]'),
#  Text(0.9222222222222223, 0.71875, 'X[6] <= 0.343\ngini = 0.147\nsamples = 50\nvalue = [4, 46]'),
#  Text(0.9111111111111111, 0.65625, 'X[3] <= 48.5\ngini = 0.332\nsamples = 19\nvalue = [4, 15]'),
#  Text(0.8888888888888888, 0.59375, 'X[4] <= 177.0\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.8777777777777778, 0.53125, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.9, 0.53125, 'X[0] <= 8.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.8888888888888888, 0.46875, 'X[4] <= 187.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.8777777777777778, 0.40625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9, 0.40625, 'X[5] <= 69.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8888888888888888, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9111111111111111, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9111111111111111, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9333333333333333, 0.59375, 'X[4] <= 184.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9222222222222223, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9444444444444444, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9333333333333333, 0.65625, 'gini = 0.0\nsamples = 31\nvalue = [0, 31]'),
#  Text(0.9777777777777777, 0.71875, 'X[0] <= 3.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.9666666666666667, 0.65625, 'X[2] <= 43.25\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.9555555555555556, 0.59375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9777777777777777, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9888888888888889, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
#!pip install graphviz
#!pip install pydotplus
# Out:
# Requirement already satisfied: graphviz in c:\users\bhassani\appdata\local\continuum\anaconda3\lib\site-packages (0.14.1)
# Collecting pydotplus
#   Downloading https://files.pythonhosted.org/packages/60/bf/62567830b700d9f6930e9ab6831d6ba256f7b0b730acb37278b0ccdffacf/pydotplus-2.0.2.tar.gz (278kB)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\bhassani\appdata\local\continuum\anaconda3\lib\site-packages (from pydotplus) (2.4.0)
# Building wheels for collected packages: pydotplus
#   Building wheel for pydotplus (setup.py): started
#   Building wheel for pydotplus (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\bhassani\AppData\Local\pip\Cache\wheels\35\7b\ab\66fb7b2ac1f6df87475b09dc48e707b6e0de80a6d8444e3628
# Successfully built pydotplus
# Installing collected packages: pydotplus
# Successfully installed pydotplus-2.0.2

# %%
import graphviz 
#import pydotplus
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data)  
print(graph)
# Out:
# <graphviz.files.Source object at 0x000001D671C5F4E0>
